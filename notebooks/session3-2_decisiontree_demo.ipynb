# %% [markdown]
# # Machine Learning Demo - Decision Tree
#
#
# Kim Hee (Graduate research assistant) <br>
# Universitätsmedizin Mannheim, Mannheim (UMM)
#
# * This is prepared for `Data analysis tools (Datenanalysewerkzeuge)` at MIRACUM summer school 2019

# %% [markdown]
# ### Protocol:
# <b>1. Import required libraries</b><br>
# </b>2. Load data ([download](https://www.kaggle.com/uciml/pima-indians-diabetes-database)) and check the label balance</b><br>
# </b>3. Split data to features and label and to train and test data</b><br>
# </b>4. Create and Train a classifier</b><br>
# </b>5. Apply the classifier to test data and print model performance</b><br>
# </b>6. Visualize the classifier</b><br>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ### Protocol:
# </b>1. Import required libraries</b><br>
# <b>2. Load data ([download](https://www.kaggle.com/uciml/pima-indians-diabetes-database)) and check the label balance</b><br>
# </b>3. Split data to features and label and to train and test data</b><br>
# </b>4. Create and Train a classifier</b><br>
# </b>5. Apply the classifier to test data and print model performance</b><br>
# </b>6. Visualize the classifier</b><br>

# %%
diabetes = pd.read_csv("data/diabetes.csv")
diabetes.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# ### Protocol:
# </b>1. Import required libraries</b><br>
# </b>2. Load data ([download](https://www.kaggle.com/uciml/pima-indians-diabetes-database)) and check the label balance</b><br>
# <b>3. Split data to features and label and to train and test data</b><br>
# </b>4. Create and Train a classifier</b><br>
# </b>5. Apply the classifier to test data and print model performance</b><br>
# </b>6. Visualize the classifier</b><br>

# %%
X = diabetes.iloc[:,:-1]
y = diabetes.Outcome # Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

# %% [markdown]
# ### Protocol:
# </b>1. Import required libraries</b><br>
# </b>2. Load data ([download](https://www.kaggle.com/uciml/pima-indians-diabetes-database)) and check the label balance</b><br>
# </b>3. Split data to features and label and to train and test data</b><br>
# <b>4. Create and Train a classifier</b><br>
# </b>5. Apply the classifier to test data and print model performance</b><br>
# </b>6. Visualize the classifier</b><br>

# %%
dt = DecisionTreeClassifier()
dt = dt.fit(X_train,y_train)

# %% [markdown]
# ### Protocol:
# </b>1. Import required libraries</b><br>
# </b>2. Load data ([download](https://www.kaggle.com/uciml/pima-indians-diabetes-database)) and check the label balance</b><br>
# </b>3. Split data to features and label and to train and test data</b><br>
# </b>4. Create and Train a classifier</b><br>
# <b>5. Apply the classifier to test data and print model performance</b><br>
# </b>6. Visualize the classifier</b><br>

# %%
y_pred = dt.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
pd.DataFrame(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.7142857142857143
#     0   1
# 0  38  10
# 1  12  17

# %% [markdown]
# ### Protocol:
# </b>1. Import required libraries</b><br>
# </b>2. Load data ([download](https://www.kaggle.com/uciml/pima-indians-diabetes-database)) and check the label balance</b><br>
# </b>3. Split data to features and label and to train and test data</b><br>
# </b>4. Create and Train a classifier</b><br>
# </b>5. Apply the classifier to test data and print model performance</b><br>
# <b>6. Visualize the classifier</b><br>

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(dt, 
                out_file = dot_data,  
                filled = True, 
                special_characters = True, 
                feature_names = X.columns, 
                class_names = ['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('images/diabetes.png')
Image(graph.create_png())
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %% [markdown]
# ### Protocol:
# </b>1. Import required libraries</b><br>
# </b>2. Load data ([download](https://www.kaggle.com/uciml/pima-indians-diabetes-database)) and check the label balance</b><br>
# </b>3. Split data to features and label and to train and test data</b><br>
# <b>4. Create and Train a classifier</b><br>
# </b>5. Apply the classifier to test data and print model performance</b><br>
# </b>6. Visualize the classifier</b><br>

# %%
dt = DecisionTreeClassifier(criterion="entropy", max_depth=2)
dt = dt.fit(X_train,y_train)

# %% [markdown]
# ### Protocol:
# </b>1. Import required libraries</b><br>
# </b>2. Load data ([download](https://www.kaggle.com/uciml/pima-indians-diabetes-database)) and check the label balance</b><br>
# </b>3. Split data to features and label and to train and test data</b><br>
# </b>4. Create and Train a classifier</b><br>
# <b>5. Apply the classifier to test data and print model performance</b><br>
# </b>6. Visualize the classifier</b><br>

# %%
y_pred = dt.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
pd.DataFrame(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.7922077922077922
#     0   1
# 0  43   5
# 1  11  18

# %% [markdown]
# ### Protocol:
# </b>1. Import required libraries</b><br>
# </b>2. Load data ([download](https://www.kaggle.com/uciml/pima-indians-diabetes-database)) and check the label balance</b><br>
# </b>3. Split data to features and label and to train and test data</b><br>
# </b>4. Create and Train a classifier</b><br>
# </b>5. Apply the classifier to test data and print model performance</b><br>
# <b>6. Visualize the classifier</b><br>

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dt, 
                out_file = dot_data,  
                filled = True, 
                special_characters = True, 
                feature_names = X.columns,
                class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('images/diabetes.png')
Image(graph.create_png())
